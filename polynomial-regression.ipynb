# %% [markdown]
# # Polynomial Linear Regression

# %% [markdown]
# ### 1. What is a polynomial regression ->

# %% [markdown]
# When the data is given is non-linear, i.e., a linear line cannot fit the line _quite_ well a polynominal model can be used there.
#
# In a polynomial regression the weights are still linear, but the inputs are raised to some powers:
# > y = b<sub>0</sub> + b<sub>1</sub>x + b<sub>2</sub>x<sup>2</sup> + ... + b<sub>n</sub>x<sup>n</sup>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = 6 * np.random.rand(100, 1) - 3
y = 0.5 * X**2 + 2 + np.random.randn(100, 1)

plt.scatter(X, y)
plt.show()

# %% [markdown]
# ### 2. Building the polynomial regression model ->

# %% [markdown]
# A ploynomial regression model can simply be built by transforming the input features. This was we will have aditional features.
#
# After the feature transformation the new features can be modeled using simple multiple linear regression.

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_features = PolynomialFeatures(degree=2, include_bias=False)
x_poly = poly_features.fit_transform(X)

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(x_poly, y)
# Out:
# LinearRegression()

# %%
X_new = np.linspace(-3, 3, 100).reshape(100, 1)
X_new_poly = poly_features.transform(X_new)
y_new = lin_reg.predict(X_new_poly)
plt.plot(X, y, "b.")
plt.plot(X_new, y_new, "r-", linewidth=2, label="Predictions")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.legend(loc="upper left", fontsize=14)
plt.axis([-3, 3, 0, 10])
plt.show()
